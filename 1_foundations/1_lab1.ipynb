# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If seven people can complete a task in ten hours working together, how long would it take for five people to complete the same task working at the same rate?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's define the problem clearly.
#
# Let \( t \) be the current time (in hours and minutes).
#
# The problem states:
#
# > "If two hours ago, it was as long after one o’clock in the afternoon as it was before one o’clock in the morning yesterday, what time is it now?"
#
# ---
#
# **Step 1: Define the reference points**
#
# - One o’clock in the afternoon: 1:00 PM on the current day.
# - One o’clock in the morning yesterday: 1:00 AM on the previous day.
#
# ---
#
# **Step 2: Set \( t \) as the current time**
#
# Two hours ago, the time was \( t - 2 \) hours.
#
# We want to find \( t \).
#
# ---
#
# **Step 3: Express the time differences**
#
# - "As long after one o’clock in the afternoon" means:
#
#   Difference between \( t - 2 \) and 1:00 PM (afternoon) on the current day.
#
# - "As long before one o’clock in the morning yesterday" means:
#
#   Difference between 1:00 AM on the previous day and \( t - 2 \).
#
# ---
#
# **Step 4: Convert times to a continuous scale**
#
# To handle times properly, let's choose a time scale. For convenience, convert all times to hours elapsed since 1:00 AM on the previous day.
#
# - 1:00 AM yesterday → time = 0
# - 1:00 PM yesterday → 12 hours (but this is not directly asked here)
# - 1:00 PM today → Since 1:00 AM yesterday is 0, then 1:00 PM today is:
#
#   Yesterday 1:00 AM + 24 hours (whole day) + 12 hours = 36 hours
#
# - Current time \( t \) (unknown)
#
# Since yesterday 1:00 AM is zero, and 1:00 PM today is 36 hours,
#
# Let's express \( t \) in number of hours after yesterday 1:00 AM.
#
# Thus,
#
# - \( t - 2 \) hours ago → current time minus 2 hours, measured relative to yesterday 1:00 AM, is \( T - 2 \).
#
# - 1:00 PM today → 36 hours after yesterday 1:00 AM.
#
# - 1:00 AM yesterday → 0 hours.
#
# ---
#
# **Step 5: Write the equation**
#
# Two hours ago (\( t - 2 \) hours), the time is *as long after 1:00 PM today (36)* as it is *before 1:00 AM yesterday (0)*.
#
# But wait: the problem says:
#
# >"Two hours ago, it was as long after one o’clock in the afternoon as it was before one o’clock in the morning yesterday."
#
# So,
#
# \[
# \text{(Two hours ago) - 1:00 PM today} = 1:00 AM yesterday - \text{(Two hours ago)}.
# \]
#
# Convert to numbers:
#
# \[
# (T - 2) - 36 = 0 - (T - 2)
# \]
#
# Simplify:
#
# \[
# T - 2 - 36 = -T + 2
# \]
#
# \[
# T - 38 = -T + 2
# \]
#
# Bring \( T \) terms to one side:
#
# \[
# T + T = 2 + 38
# \]
#
# \[
# 2T = 40
# \]
#
# \[
# T = 20
# \]
#
# ---
#
# **Step 6: Interpret the result**
#
# - \( T = 20 \) hours after 1:00 AM yesterday.
#
# Since 1:00 AM yesterday is time zero,
#
# - 20 hours after 1:00 AM yesterday is:
#
# 1:00 AM + 20 hours = 9:00 PM yesterday.
#
# But wait -- the current time \( t \) = 20 hours after 1:00 AM yesterday, which is 9:00 PM yesterday.
#
# But the problem context is about the current time.
#
# Since \( t \) is the current time, and it is 9:00 PM *yesterday*, that can't be the current time. The current time must be later than that, at least past midnight.
#
# The misunderstanding is in how we defined T.
#
# To clarify, let's convert the \( T = 20 \) back to a full 24-hour clock.
#
# - 20 hours after 1:00 AM yesterday → 21:00 (9:00 PM) yesterday.
#
# But since the problem references "two hours ago", and \( t - 2 = 18 \) (6:00 PM yesterday), which is before 1:00 PM today (36).
#
# This causes discrepancy because \( t-2 \) should be between yesterday 1:00 AM (0) and today 1:00 PM (36), but our initial assumption was that 1:00 PM today is 36, which is 1:00 PM (today).
#
# Let's re-express times in absolute terms.
#
# ---
#
# **Step 7: Another approach**
#
# Alternatively, let’s calculate times relative to midnight today.
#
# - One o’clock in the morning yesterday: 1:00 AM yesterday = midnight today - 24 + 1 = -23 hours (if now is time zero at midnight today).
#
# - One o’clock in the afternoon today: 1:00 PM today = 13 hours.
#
# If current time \( t \) is measured in hours from midnight today.
#
# The time two hours ago:
#
# \[
# t - 2
# \]
#
# Difference from 1:00 PM today is:
#
# \[
# (t - 2) - 13 = t - 15
# \]
#
# Difference from 1:00 AM yesterday is:
#
# \[
# (t - 2) - (-23) = t - 2 + 23 = t + 21
# \]
#
# But the problem says: "two hours ago, it was as long after 1 PM as it was before 1 AM yesterday."
#
# - "As long after 1 PM": the amount of time after 1 PM = \((t - 2) - 13 = t - 15\)
#
# - "As long before 1 AM yesterday": the amount of time before 1 AM yesterday = \(1\ \text{o’clock yesterday} - (t - 2) = -23 - (t - 2) = -23 - t + 2 = -t - 21\). This is negative which doesn't fit "as long before".
#
# But time before means positive, so:
#
# \[
# \text{Time before 1 AM yesterday} = (t - 2) - (-23) = t + 21
# \]
#
# This is time after the reference point, so "before 1 AM yesterday" must be measured the other way.
#
# Actually, the problem says:
#
# > as long after 1 PM as it was before 1 AM yesterday.
#
# "Was as long after 1 PM" means (time two hours ago - 1 PM) positive
#
# "Was as long before 1 AM yesterday" means (1 AM yesterday - time two hours ago) positive
#
# So the formula is:
#
# \[
# (t - 2) - 13 =  -23 - (t - 2)
# \]
#
# Because
#
# Before 1 AM yesterday = 1 AM yesterday - time two hours ago
#
# \[
# \Rightarrow t - 2 - 13 = -23 - (t - 2)
# \]
#
# Simplify:
#
# \[
# t - 15 = -23 - t + 2
# \]
#
# \[
# t - 15 = -21 - t
# \]
#
# Bring all \( t \) terms to one side:
#
# \[
# t + t = -21 + 15
# \]
#
# \[
# 2t = -6
# \]
#
# \[
# t = -3
# \]
#
# ---
#
# **Step 8: Interpret this result**
#
# - \( t = -3 \) means current time is 3 hours before midnight today, i.e., 9:00 PM yesterday.
#
# Therefore:
#
# - Current time = 9:00 PM yesterday.
#
# But this can't be the present time.
#
# The question probably expects the time in the current day.
#
# ---
#
# **Step 9: The only way this makes sense**
#
# The question implies the answer is probably a time between 1 PM (today) and 1 AM (yesterday).
#
# Between 1 AM yesterday to 1 PM today is a 36-hour window.
#
# Alternatively, the question might mean 1 PM *on the previous day* and 1 AM on the current day.
#
# Or rewriting:
#
# - "It was as long after 1 o’clock in the afternoon [today]" as it was before 1 o’clock in the morning yesterday.
#
# Meaning:
#
# Two hours ago time difference from 1 PM today = difference from 1 AM yesterday to two hours ago.
#
# Let’s denote:
#
# - Two hours ago = \( s \)
#
# - Then the equation:
#
# \[
# s - 13 = 1 - 24 - s \quad \Rightarrow \quad s - 13 = -23 - s
# \]
#
# This is the same as before.
#
# Add \( s \) both sides:
#
# \[
# s + s = -23 + 13
# \]
#
# \[
# 2s = -10
# \]
#
# \[
# s = -5
# \]
#
# \( s = -5 \) means 5 hours before midnight today = 7 PM yesterday.
#
# Therefore,
#
# Current time \( t = s + 2 = -5 + 2 = -3 \).
#
# Again \( t = -3 \rightarrow 9 \) PM yesterday.
#
# ---
#
# **Step 10: Summary**
#
# If "two hours ago, it was as long after one o’clock in the afternoon as it was before one o’clock in the morning yesterday," then the current time is 9:00 PM yesterday.
#
# That implies the question might be misinterpreted since time cannot be in the past.
#
# ---
#
# **Step 11: This problem is a classic**
#
# This is a classic clock problem involving symmetry.
#
# Another common way to do it:
#
# Let \( x \) be the number of hours after 1 PM (today) that two hours ago corresponds to.
#
# So, two hours ago = 1 PM + \( x \)
#
# Then,
#
# Time before 1 AM yesterday = same as time after 1 PM today two hours ago:
#
# \[
# \text{Difference after 1 PM today} = x
# \]
#
# \[
# \text{Difference before 1 AM yesterday} = 24 - (x + 14) = 10 - x
# \]
#
# Where does 14 come from?
#
# From 1 PM today back to 1 AM yesterday is 36 hours, which is 24 + 12 hours = 36.
#
# Wait, let's compute total time between 1 AM yesterday and 1 PM today:
#
# - From 1 AM yesterday to midnight yesterday: 23 hours
#
# - Midnight to 1 PM today: 13 hours
#
# Total = 23 + 13 = 36 hours
#
# Two hours ago is at:
#
# \[
# 1 PM + x = 13 + x  \text{ (in hours after midnight today)}
# \]
#
# Difference from 1 AM yesterday (which is 1 AM yesterday = -23 or 1 AM yesterday = day -1 hour 1):
#
# The time between 1 PM today and 1 AM yesterday is 36 hours.
#
# So if two hours ago is \( 13 + x \) hours after midnight today,
#
# then difference to 1 AM yesterday is:
#
# \[
# 36 - x
# \]
#
# (assuming differences in the same units)
#
# "Two hours ago, it was as long after 1 PM as it was before 1 AM yesterday."
#
# In other words,
#
# \[
# x = 36 - x
# \]
#
# \[
# 2x = 36
# \]
#
# \[
# x = 18
# \]
#
# ---
#
# Therefore,
#
# Two hours ago was 18 hours after 1 PM today:
#
# Two hours ago = 1 PM + 18 hours = 1 PM + 18 hours = 7 AM tomorrow
#
# But this is impossible because two hours ago is in the past relative to current time.
#
# Therefore, the current time is:
#
# \[
# t = (1 PM + 18\ \text{hours}) + 2 \text{ hours} = 1 PM + 20\ \text{hours} = 9 AM \text{ next day}
# \]
#
# ---
#
# **Step 12: Verify**
#
# 1 PM today + 20 hours = 1 PM + 24 hours - 4 hours = 1 PM + 1 day - 4 hours = 9 AM next day.
#
# It makes sense.
#
# ---
#
# **Step 13: Final answer**
#
# Current time is 9:00 AM the following day (after 1 PM today).
#
# ---
#
# **Summary**:
#
# - Let two hours ago be \( t - 2 \)
#
# - Time after 1 PM today = \( t - 2 - 13 = x \)
#
# - Time before 1 AM yesterday = total duration between 1 AM yesterday and 1 PM today is 36; so
#
# \[
# \text{time before 1 AM yesterday} = 36 - x
# \]
#
# Set equal:
#
# \[
# x = 36 - x \implies 2x = 36 \implies x=18
# \]
#
# Solve for \( t \):
#
# \[
# t - 2 - 13 = 18 \implies t - 15 = 18 \implies t = 33
# \]
#
# Time as hours after midnight today:
#
# 33 hours after midnight today is:
#
# - 24 hours = midnight next day
#
# - Additional 9 hours = 9 AM next day
#
# ---
#
# ### **Answer:**
#
# \[
# \boxed{9:00\ \text{AM next day}}
# \]

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's define the problem clearly.
#
# Let \( t \) be the current time (in hours and minutes).
#
# The problem states:
#
# > "If two hours ago, it was as long after one o’clock in the afternoon as it was before one o’clock in the morning yesterday, what time is it now?"
#
# ---
#
# **Step 1: Define the reference points**
#
# - One o’clock in the afternoon: 1:00 PM on the current day.
# - One o’clock in the morning yesterday: 1:00 AM on the previous day.
#
# ---
#
# **Step 2: Set \( t \) as the current time**
#
# Two hours ago, the time was \( t - 2 \) hours.
#
# We want to find \( t \).
#
# ---
#
# **Step 3: Express the time differences**
#
# - "As long after one o’clock in the afternoon" means:
#
#   Difference between \( t - 2 \) and 1:00 PM (afternoon) on the current day.
#
# - "As long before one o’clock in the morning yesterday" means:
#
#   Difference between 1:00 AM on the previous day and \( t - 2 \).
#
# ---
#
# **Step 4: Convert times to a continuous scale**
#
# To handle times properly, let's choose a time scale. For convenience, convert all times to hours elapsed since 1:00 AM on the previous day.
#
# - 1:00 AM yesterday → time = 0
# - 1:00 PM yesterday → 12 hours (but this is not directly asked here)
# - 1:00 PM today → Since 1:00 AM yesterday is 0, then 1:00 PM today is:
#
#   Yesterday 1:00 AM + 24 hours (whole day) + 12 hours = 36 hours
#
# - Current time \( t \) (unknown)
#
# Since yesterday 1:00 AM is zero, and 1:00 PM today is 36 hours,
#
# Let's express \( t \) in number of hours after yesterday 1:00 AM.
#
# Thus,
#
# - \( t - 2 \) hours ago → current time minus 2 hours, measured relative to yesterday 1:00 AM, is \( T - 2 \).
#
# - 1:00 PM today → 36 hours after yesterday 1:00 AM.
#
# - 1:00 AM yesterday → 0 hours.
#
# ---
#
# **Step 5: Write the equation**
#
# Two hours ago (\( t - 2 \) hours), the time is *as long after 1:00 PM today (36)* as it is *before 1:00 AM yesterday (0)*.
#
# But wait: the problem says:
#
# >"Two hours ago, it was as long after one o’clock in the afternoon as it was before one o’clock in the morning yesterday."
#
# So,
#
# \[
# \text{(Two hours ago) - 1:00 PM today} = 1:00 AM yesterday - \text{(Two hours ago)}.
# \]
#
# Convert to numbers:
#
# \[
# (T - 2) - 36 = 0 - (T - 2)
# \]
#
# Simplify:
#
# \[
# T - 2 - 36 = -T + 2
# \]
#
# \[
# T - 38 = -T + 2
# \]
#
# Bring \( T \) terms to one side:
#
# \[
# T + T = 2 + 38
# \]
#
# \[
# 2T = 40
# \]
#
# \[
# T = 20
# \]
#
# ---
#
# **Step 6: Interpret the result**
#
# - \( T = 20 \) hours after 1:00 AM yesterday.
#
# Since 1:00 AM yesterday is time zero,
#
# - 20 hours after 1:00 AM yesterday is:
#
# 1:00 AM + 20 hours = 9:00 PM yesterday.
#
# But wait -- the current time \( t \) = 20 hours after 1:00 AM yesterday, which is 9:00 PM yesterday.
#
# But the problem context is about the current time.
#
# Since \( t \) is the current time, and it is 9:00 PM *yesterday*, that can't be the current time. The current time must be later than that, at least past midnight.
#
# The misunderstanding is in how we defined T.
#
# To clarify, let's convert the \( T = 20 \) back to a full 24-hour clock.
#
# - 20 hours after 1:00 AM yesterday → 21:00 (9:00 PM) yesterday.
#
# But since the problem references "two hours ago", and \( t - 2 = 18 \) (6:00 PM yesterday), which is before 1:00 PM today (36).
#
# This causes discrepancy because \( t-2 \) should be between yesterday 1:00 AM (0) and today 1:00 PM (36), but our initial assumption was that 1:00 PM today is 36, which is 1:00 PM (today).
#
# Let's re-express times in absolute terms.
#
# ---
#
# **Step 7: Another approach**
#
# Alternatively, let’s calculate times relative to midnight today.
#
# - One o’clock in the morning yesterday: 1:00 AM yesterday = midnight today - 24 + 1 = -23 hours (if now is time zero at midnight today).
#
# - One o’clock in the afternoon today: 1:00 PM today = 13 hours.
#
# If current time \( t \) is measured in hours from midnight today.
#
# The time two hours ago:
#
# \[
# t - 2
# \]
#
# Difference from 1:00 PM today is:
#
# \[
# (t - 2) - 13 = t - 15
# \]
#
# Difference from 1:00 AM yesterday is:
#
# \[
# (t - 2) - (-23) = t - 2 + 23 = t + 21
# \]
#
# But the problem says: "two hours ago, it was as long after 1 PM as it was before 1 AM yesterday."
#
# - "As long after 1 PM": the amount of time after 1 PM = \((t - 2) - 13 = t - 15\)
#
# - "As long before 1 AM yesterday": the amount of time before 1 AM yesterday = \(1\ \text{o’clock yesterday} - (t - 2) = -23 - (t - 2) = -23 - t + 2 = -t - 21\). This is negative which doesn't fit "as long before".
#
# But time before means positive, so:
#
# \[
# \text{Time before 1 AM yesterday} = (t - 2) - (-23) = t + 21
# \]
#
# This is time after the reference point, so "before 1 AM yesterday" must be measured the other way.
#
# Actually, the problem says:
#
# > as long after 1 PM as it was before 1 AM yesterday.
#
# "Was as long after 1 PM" means (time two hours ago - 1 PM) positive
#
# "Was as long before 1 AM yesterday" means (1 AM yesterday - time two hours ago) positive
#
# So the formula is:
#
# \[
# (t - 2) - 13 =  -23 - (t - 2)
# \]
#
# Because
#
# Before 1 AM yesterday = 1 AM yesterday - time two hours ago
#
# \[
# \Rightarrow t - 2 - 13 = -23 - (t - 2)
# \]
#
# Simplify:
#
# \[
# t - 15 = -23 - t + 2
# \]
#
# \[
# t - 15 = -21 - t
# \]
#
# Bring all \( t \) terms to one side:
#
# \[
# t + t = -21 + 15
# \]
#
# \[
# 2t = -6
# \]
#
# \[
# t = -3
# \]
#
# ---
#
# **Step 8: Interpret this result**
#
# - \( t = -3 \) means current time is 3 hours before midnight today, i.e., 9:00 PM yesterday.
#
# Therefore:
#
# - Current time = 9:00 PM yesterday.
#
# But this can't be the present time.
#
# The question probably expects the time in the current day.
#
# ---
#
# **Step 9: The only way this makes sense**
#
# The question implies the answer is probably a time between 1 PM (today) and 1 AM (yesterday).
#
# Between 1 AM yesterday to 1 PM today is a 36-hour window.
#
# Alternatively, the question might mean 1 PM *on the previous day* and 1 AM on the current day.
#
# Or rewriting:
#
# - "It was as long after 1 o’clock in the afternoon [today]" as it was before 1 o’clock in the morning yesterday.
#
# Meaning:
#
# Two hours ago time difference from 1 PM today = difference from 1 AM yesterday to two hours ago.
#
# Let’s denote:
#
# - Two hours ago = \( s \)
#
# - Then the equation:
#
# \[
# s - 13 = 1 - 24 - s \quad \Rightarrow \quad s - 13 = -23 - s
# \]
#
# This is the same as before.
#
# Add \( s \) both sides:
#
# \[
# s + s = -23 + 13
# \]
#
# \[
# 2s = -10
# \]
#
# \[
# s = -5
# \]
#
# \( s = -5 \) means 5 hours before midnight today = 7 PM yesterday.
#
# Therefore,
#
# Current time \( t = s + 2 = -5 + 2 = -3 \).
#
# Again \( t = -3 \rightarrow 9 \) PM yesterday.
#
# ---
#
# **Step 10: Summary**
#
# If "two hours ago, it was as long after one o’clock in the afternoon as it was before one o’clock in the morning yesterday," then the current time is 9:00 PM yesterday.
#
# That implies the question might be misinterpreted since time cannot be in the past.
#
# ---
#
# **Step 11: This problem is a classic**
#
# This is a classic clock problem involving symmetry.
#
# Another common way to do it:
#
# Let \( x \) be the number of hours after 1 PM (today) that two hours ago corresponds to.
#
# So, two hours ago = 1 PM + \( x \)
#
# Then,
#
# Time before 1 AM yesterday = same as time after 1 PM today two hours ago:
#
# \[
# \text{Difference after 1 PM today} = x
# \]
#
# \[
# \text{Difference before 1 AM yesterday} = 24 - (x + 14) = 10 - x
# \]
#
# Where does 14 come from?
#
# From 1 PM today back to 1 AM yesterday is 36 hours, which is 24 + 12 hours = 36.
#
# Wait, let's compute total time between 1 AM yesterday and 1 PM today:
#
# - From 1 AM yesterday to midnight yesterday: 23 hours
#
# - Midnight to 1 PM today: 13 hours
#
# Total = 23 + 13 = 36 hours
#
# Two hours ago is at:
#
# \[
# 1 PM + x = 13 + x  \text{ (in hours after midnight today)}
# \]
#
# Difference from 1 AM yesterday (which is 1 AM yesterday = -23 or 1 AM yesterday = day -1 hour 1):
#
# The time between 1 PM today and 1 AM yesterday is 36 hours.
#
# So if two hours ago is \( 13 + x \) hours after midnight today,
#
# then difference to 1 AM yesterday is:
#
# \[
# 36 - x
# \]
#
# (assuming differences in the same units)
#
# "Two hours ago, it was as long after 1 PM as it was before 1 AM yesterday."
#
# In other words,
#
# \[
# x = 36 - x
# \]
#
# \[
# 2x = 36
# \]
#
# \[
# x = 18
# \]
#
# ---
#
# Therefore,
#
# Two hours ago was 18 hours after 1 PM today:
#
# Two hours ago = 1 PM + 18 hours = 1 PM + 18 hours = 7 AM tomorrow
#
# But this is impossible because two hours ago is in the past relative to current time.
#
# Therefore, the current time is:
#
# \[
# t = (1 PM + 18\ \text{hours}) + 2 \text{ hours} = 1 PM + 20\ \text{hours} = 9 AM \text{ next day}
# \]
#
# ---
#
# **Step 12: Verify**
#
# 1 PM today + 20 hours = 1 PM + 24 hours - 4 hours = 1 PM + 1 day - 4 hours = 9 AM next day.
#
# It makes sense.
#
# ---
#
# **Step 13: Final answer**
#
# Current time is 9:00 AM the following day (after 1 PM today).
#
# ---
#
# **Summary**:
#
# - Let two hours ago be \( t - 2 \)
#
# - Time after 1 PM today = \( t - 2 - 13 = x \)
#
# - Time before 1 AM yesterday = total duration between 1 AM yesterday and 1 PM today is 36; so
#
# \[
# \text{time before 1 AM yesterday} = 36 - x
# \]
#
# Set equal:
#
# \[
# x = 36 - x \implies 2x = 36 \implies x=18
# \]
#
# Solve for \( t \):
#
# \[
# t - 2 - 13 = 18 \implies t - 15 = 18 \implies t = 33
# \]
#
# Time as hours after midnight today:
#
# 33 hours after midnight today is:
#
# - 24 hours = midnight next day
#
# - Additional 9 hours = 9 AM next day
#
# ---
#
# ### **Answer:**
#
# \[
# \boxed{9:00\ \text{AM next day}}
# \]

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

question_1 = "Please pick a business area that might be worth exploring for Agentic AI opportunity"
question_2 = "Present a pain-point in that industry in" + question_1 + "something challenging that could be solved by Agentic AI"
question_3 = "Present a solution to the pain-point in" + question_2 + "that could be solved by Agentic AI"

messages_1 = [{"role": "user", "content": question_1}]
messages_2 = [{"role": "user", "content": question_2}]
messages_3 = [{"role": "user", "content": question_3}]

# response = openai.chat.completions.create(
#     model="gpt-4.1-mini",
#     messages=messages
# )

# question = response.choices[0].message.content

# print(question) 

# Then make the first call:

response_1 = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages_1
)

response_2 = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages_2
)

response_3 = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages_3
)   

business_idea = response_1.choices[0].message.content
pain_point = response_2.choices[0].message.content
solution = response_3.choices[0].message.content

print(business_idea)
print(pain_point)
print(solution)

# messages_2 = [{"role": "user", "content": question_2 + business_idea}]
# Out:
# One promising business area for exploring an Agentic AI opportunity is **Personalized Healthcare Management**.
#
# ### Why Personalized Healthcare Management?
#
# 1. **Complex Decision-Making**: Healthcare involves complex, multi-step decisions, such as diagnosing conditions, recommending treatments, managing medication schedules, and coordinating with multiple healthcare providers. An agentic AI can operate autonomously to navigate these complexities.
#
# 2. **Personalization Demand**: Patients increasingly expect highly personalized care plans tailored to their unique genetics, lifestyle, and medical history. An agentic AI can analyze vast data sources and continuously adapt recommendations.
#
# 3. **Continuous Monitoring & Proactivity**: Wearables and IoT devices provide constant health data. An agentic AI can act proactively, alerting patients and caregivers about potential health issues before they escalate.
#
# 4. **Operational Efficiency**: It can handle routine administrative or communication tasks such as appointment scheduling, reminders, medical record updates, and insurance claims, reducing the burden on healthcare professionals.
#
# 5. **Regulatory and Ethical Guardrails**: With careful design to comply with healthcare regulations and privacy standards (e.g., HIPAA, GDPR), an agentic AI can build trust while enhancing quality of care.
#
# ### Potential Agentic AI Features in this Area
#
# - Autonomous symptom checking and triage.
# - Dynamic treatment adjustment based on real-time data.
# - Proactive health coaching for chronic disease management.
# - Coordinating multi-specialist inputs into a unified treatment plan.
# - Managing patient adherence to medication and lifestyle modifications.
#
# ### Market Opportunity
#
# - Aging populations globally increase demand for personalized long-term care.
# - Healthcare costs can be reduced by preventing hospitalizations and complications.
# - Insurers and providers remain interested in tools that improve patient outcomes.
#
# ---
#
# If you'd like, I can help brainstorm specific product ideas, business models, or technical approaches within this space!
# Certainly! Let’s consider the **Supply Chain and Logistics** industry—a sector ripe for innovation with agentic AI.
#
# **Pain-point:**
# One major challenge in supply chain management is the **dynamic and complex nature of demand forecasting and inventory optimization** across multiple nodes (manufacturers, warehouses, retailers). Existing solutions often rely on static models or human oversight, leading to delayed responses to disruptions such as sudden demand spikes, supply shortages, or transportation delays.
#
# **How Agentic AI can help:**
# Agentic AI systems, capable of autonomous decision-making and proactive problem-solving, could dynamically monitor real-time data (sales trends, weather, geopolitical events, transportation conditions) and autonomously adjust orders, reroute shipments, and coordinate with multiple stakeholders to prevent stockouts or overstock situations without human intervention. Such an AI could act as a self-managing supply chain agent, optimizing operations end-to-end in a fast-changing environment.
#
# This would reduce costs, improve resilience, and enhance customer satisfaction—offering significant value for businesses.
# Certainly! Let's explore a pain-point in the **supply chain and logistics** industry, a sector ripe for innovation with Agentic AI.
#
# ---
#
# ### Industry: Supply Chain and Logistics
#
# #### Pain-Point:
# **Complexity and unpredictability in supply chain operations lead to inefficiencies, delays, and increased costs.**
#
# Supply chains today involve multiple stakeholders, from suppliers and manufacturers to distributors and retailers. The coordination among these entities is fraught with challenges such as:
#
# - Demand forecasting errors leading to stockouts or overstock.
# - Unexpected disruptions (weather, geopolitical issues, transportation delays).
# - Incomplete or delayed information sharing across the chain.
# - Manual and siloed decision-making causing slow response to evolving situations.
#
# This complexity results in lost revenue, unhappy customers, and waste.
#
# ---
#
# ### How Agentic AI Can Solve This:
#
# **Agentic AI** refers to autonomous agents capable of perceiving their environment, reasoning about it, and taking proactive decisions to achieve goals. Applying Agentic AI in supply chains can transform operations by creating an intelligent, adaptive, and collaborative network of agents.
#
# #### Proposed Solution:
#
# - **Autonomous Decision Agents for Each Node**: Deploy AI agents at supplier, warehouse, transport, and retail nodes that continuously monitor real-time data (inventory, shipments, demand forecasts, traffic/weather).
#
# - **Collaborative Multi-Agent Coordination**: These agents autonomously communicate and coordinate with each other to optimize scheduling, reroute shipments, adjust production plans, and manage inventory dynamically.
#
# - **Predictive and Adaptive Response**: Using predictive modeling, agents anticipate disruptions (e.g., port closures, demand spikes) and proactively adjust plans by reallocating resources or suggesting alternatives.
#
# - **End-to-End Visibility and Control**: Centralized supervisory AI monitors overall supply chain health, ensuring local agent decisions align with global goals (minimizing costs, meeting service levels).
#
# ---
#
# ### Benefits:
#
# - **Increased agility and resilience** to disruptions.
# - **Lower operational costs** by reducing manual interventions and waste.
# - **Improved customer satisfaction** through better fulfillment rates and transparency.
# - **Scalable and flexible operations** that adapt in real-time without human delays.
#
# ---
#
# ### Summary
#
# The **supply chain industry** suffers from complexity and unpredictability that traditional tools can’t fully manage. Deploying **Agentic AI** creates an autonomous, intelligent network of agents capable of self-coordination and adaptive problem-solving. This has the potential to revolutionize supply chain management by making it more responsive, efficient, and resilient.
#
# ---
#
# If you'd like, I can help draft a more detailed implementation plan or explore other industries!
